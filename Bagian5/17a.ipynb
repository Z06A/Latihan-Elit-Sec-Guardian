# %% [markdown]
# ### Membangun Otentikasi Pengguna yang Aman: HTML, CSS, JS, PHP
#
# **Peraturan:**
#
# - Tujuan dari latihan ini adalah untuk menerapkan sistem otentikasi pengguna ultra-canggih.
# - Anda diberikan satu file HTML yang menyertakan kode yang diperlukan untuk sistem otentikasi.
#
# Tugas Anda adalah menyelesaikan bagian TODO dalam kode untuk mengimplementasikan fungsionalitas yang diperlukan.
#
# - Terapkan validasi sisi klien untuk formulir login menggunakan HTML, CSS, dan JavaScript untuk memastikan bahwa bidang nama pengguna dan kata sandi diisi sebelum pengiriman.
# - Ubah kode JavaScript untuk melakukan tindakan yang diperlukan ketika formulir dikirimkan, seperti menangani validasi formulir dan membuat permintaan AJAX untuk otentikasi sisi server.
# - Di bagian PHP, tulis logika untuk otentikasi sisi server. Validasi nama pengguna dan kata sandi yang dikirimkan, dan kembalikan respons yang sesuai berdasarkan hasil autentikasi.
# - Pertimbangkan praktik terbaik keamanan, seperti mencegah serangan injeksi SQL dan menyimpan kata sandi dengan aman menggunakan teknik hashing dan salting.
# - Uji implementasi Anda secara menyeluruh untuk memastikan fungsionalitas dan keamanan yang tepat.
# - Jangan ragu untuk menggunakan pustaka atau kerangka kerja tambahan jika diperlukan, tetapi pastikan untuk membenarkan penggunaannya.
#
# **Catatan:** Latihan ini bertujuan untuk menantang keterampilan Anda dalam membangun sistem otentikasi pengguna yang aman. Perhatikan aspek fungsionalitas dan keamanan saat menyelesaikan latihan.
#
# **Menerapkan:**
#
# - Menerapkan otentikasi pengguna yang aman (HTML, CSS, JS, PHP).
# - Mencegah kerentanan web (SQLi, XSS).
# - Simpan kata sandi dengan aman (hashing, salting).
# - Menerapkan manajemen sesi yang aman.
# - Uji keamanan
#
# **Code html:**

# %%
<!DOCTYPE html>
<html>
<head>
  <title>Build Your Own Authentication System</title>
  <style>
    body {
      font-family: Arial, sans-serif;
      margin: 20px;
    }
    h1 {
      text-align: center;
      margin-bottom: 20px;
    }
    p {
      margin-bottom: 10px;
    }
    code {
      background-color: #f2f2f2;
      padding: 2px 4px;
      border-radius: 4px;
    }
    pre {
      background-color: #f2f2f2;
      padding: 10px;
      border-radius: 4px;
    }
  </style>
</head>
<body>
  <h1>Build Your Own Authentication System</h1>

  <h2>Instructions:</h2>
  <p>Welcome to the authentication system building exercise! Your task is to build a simple user authentication system using HTML, CSS, and JavaScript. Follow the steps below to complete the exercise:</p>

  <ol>
    <li>Create an HTML form that includes fields for username and password input. Wrap the form inside a container element.</li>
    <li>Add client-side validation to ensure that both the username and password fields are filled in before submission. Display an error message if either field is empty.</li>
    <li>Implement an AJAX request in JavaScript to send the form data to the server for authentication.</li>
    <li>Create a server-side script (e.g., PHP or Node.js) to handle the authentication logic. Validate the submitted username and password, and return appropriate responses based on the authentication result.</li>
    <li>Display a success message or an error message on the client-side based on the response received from the server.</li>
    <li>Style the form and error messages using CSS to make it visually appealing.</li>
    <li>Test your implementation thoroughly to ensure it functions correctly and securely.</li>
  </ol>

  <h2>Code Starter:</h2>
  <p>Here's a code starter to help you get started with the exercise:</p>

  <pre><code>&lt;!DOCTYPE html&gt;
&lt;html&gt;
&lt;head&gt;
  &lt;title&gt;User Authentication&lt;/title&gt;
  &lt;!-- Add your CSS styles here --&gt;
&lt;/head&gt;
&lt;body&gt;
  &lt;div id="container"&gt;
    &lt;h2&gt;User Authentication&lt;/h2&gt;
    &lt;form id="authForm"&gt;
      &lt;!-- Add your form fields here --&gt;
      &lt;button type="submit"&gt;Submit&lt;/button&gt;
    &lt;/form&gt;
    &lt;p id="errorMessage"&gt;&lt;/p&gt;
  &lt;/div&gt;

  &lt;script&gt;
    // Add your JavaScript code here
  &lt;/script&gt;
&lt;/body&gt;
&lt;/html&gt;</code></pre>

  <h2>Submission:</h2>
  <p>Once you have completed building your authentication system, make sure to submit the following files:</p>
  <ul>
    <li><strong>index.html:</strong> The HTML file containing your authentication system code.</li>
    <li><strong>style.css:</strong> (optional) The CSS file containing your custom styles.</li>
    <li><strong>script.js:</strong> (optional) The JavaScript file containing your custom code.</li>
    <li><strong>server.php</strong> or <strong>server.js:</strong> The server-side script handling the authentication logic.</li>
  </ul>
  
  <p>Good luck with the exercise! Have fun building your own authentication system!</p>
</body>
</html>

# %% [markdown]
# #### Bangun Sistem Autentikasi Anda Sendiri
#
# **Petunjuk:**
#
# Selamat datang di latihan membangun sistem autentikasi! Tugas Anda adalah membangun sistem autentikasi pengguna sederhana menggunakan HTML, CSS, dan JavaScript.
#
# **Ikuti langkah-langkah di bawah ini untuk menyelesaikan latihan:**
#
# - 1.Buat formulir HTML yang menyertakan kolom untuk memasukkan nama pengguna dan kata sandi. Bungkus formulir di dalam elemen kontainer.
# - 2.Tambahkan validasi sisi klien untuk memastikan bahwa kolom nama pengguna dan kata sandi diisi sebelum pengiriman.
# Tampilkan pesan kesalahan jika salah satu kolom kosong.
# - 3.Terapkan permintaan AJAX dalam JavaScript untuk mengirim data formulir ke server untuk autentikasi.
# - 4.Buat skrip sisi server (misalnya, PHP atau Node.js) untuk menangani logika autentikasi. Validasi nama pengguna dan kata sandi yang dikirimkan, dan berikan respons yang sesuai berdasarkan hasil autentikasi.
# - 5.Tampilkan pesan berhasil atau pesan kesalahan di sisi klien berdasarkan respons yang diterima dari server.
# - 6.Tata formulir dan pesan kesalahan menggunakan CSS agar menarik secara visual.
# - 7.Uji implementasi Anda secara menyeluruh untuk memastikannya berfungsi dengan benar dan aman.
#
# **Pemula Kode:**
#
# #### Berikut ini adalah pembuka kode untuk membantu Anda memulai latihan:

# %%
<!DOCTYPE html>
<html>
<head>
<title>Autentikasi Pengguna</title>
<!-- Tambahkan gaya CSS Anda di sini -->
</ head>
<body>
<div id="container">
<h2>Autentikasi Pengguna</h2>
<form id="authForm">
<!-- Tambahkan kolom formulir Anda di sini -->
<button type="submit"> Kirim</button>
</form>
<p id="errorMessage"></p>
</div>

<script>
// Tambahkan kode JavaScript Anda di sini
</script>
</body>
</html>

# %% [markdown]
# **Pengiriman:**
#
# Setelah Anda selesai membangun sistem autentikasi, pastikan untuk mengirimkan file berikut:
#
# - **index.html:** File HTML yang berisi kode sistem autentikasi Anda.
#
# - **style.css:** (opsional) File CSS yang berisi gaya khusus Anda.
#
# - **script.js:** (opsional) File JavaScript yang berisi kode kustom Anda.
#
# - **server.php atau server.js:** Skrip sisi server yang menangani logika autentikasi.
#
#  Semoga berhasil dengan latihan ini! Selamat membangun sistem autentikasi Anda sendiri!
